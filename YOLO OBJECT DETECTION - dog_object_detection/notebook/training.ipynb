# %%
### 1. Mount Google Drive ###

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 977.1/977.1 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 33.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 33.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
ROOT_DIR = '/content/gdrive/MyDrive/Colab Notebooks/YOLO'

# %%
model = YOLO("yolo11n.yaml")  # build a new model from scratch

# %%
import os
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=30)  # train the model
# Out:
# Ultralytics 8.3.100 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source='/content/drive/MyDrive/Colab Notebooks/YOLO/Validation/images' save=True
# Out:
# Ultralytics 8.3.100 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/100 /content/drive/MyDrive/Colab Notebooks/YOLO/Validation/images/00ecc67a6c3a048c.jpg: 448x640 2 DOGs, 286.5ms
# image 2/100 /content/drive/MyDrive/Colab Notebooks/YOLO/Validation/images/05d5d6694d4c6bd2.jpg: 416x640 1 DOG, 284.8ms
# image 3/100 /content/drive/MyDrive/Colab Notebooks/YOLO/Validation/images/0902a1530b944de5.jpg: 448x640 1 DOG, 186.2ms
# image 4/100 /content/drive/MyDrive/Colab Notebooks/YOLO/Validation/images/0aad2bb810a03966.jpg: 480x640 1 DOG, 195.4ms
# image 5/100 /content/drive/MyDrive/Colab Notebooks/YOLO/Validation/images/0f731adcd7458c2b.jpg: 480x640 1 DOG, 163.2ms
# image 6/100 /content/drive/MyDrive/Colab Notebooks/YOLO/Validation/images/121f6fedb3af41ba.jpg: 480x640 1 DOG, 164.9ms
# ...
